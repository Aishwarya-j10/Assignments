# %%
import numpy as np 
import pandas as pd

# %%
# Loading The DATASET : 

df = pd.read_csv("trade.csv") 
df
# Out:
#       country_or_area  year  comm_code  \
# 0           Australia  2016      10111
# 1           Australia  2016      10119
# 2           Australia  2016      10119
# 3           Australia  2016      10119
# 4           Australia  2016      10120
# ...               ...   ...        ...
# 59085          Canada  1989     121300
# 59086          Canada  1989     121410
# 59087          Canada  1989     121410
# 59088          Canada  1989     121490
# 59089          Canada  1989     121490
#
#                                            commodity       flow  trade_usd  \
# 0                    Horses, live pure-bred breeding     Export  128577553
# 1             Horses, live except pure-bred breeding  Re-Import    4928989
# 2             Horses, live except pure-bred breeding     Export   11812782
# 3             Horses, live except pure-bred breeding     Import   90430302
# 4                     Asses, mules and hinnies, live     Export      58473
# ...

# %%
top_2000_rows = df.head(2000) 
top_2000_rows.to_csv("trade1.csv", index = False)
